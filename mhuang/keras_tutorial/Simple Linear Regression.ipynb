# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using Theano backend.
# WARNING (theano.sandbox.cuda): CUDA is installed, but device gpu is not available  (error: Unable to get the number of gpus available: unknown error)

# %%
# Generate dataset
trX = np.linspace(-1, 1, 101)
trY = 2*trX + np.random.randn(*trX.shape) * 0.33 # create a y value which is approximately linear but with some random noise

# %%
plt.plot(trX, trY, label='data')

# %%
# Linear regression model
model = Sequential()
model.add(Dense(input_dim=1, output_dim=1, init='uniform', activation='linear'))
model.compile(optimizer='sgd', loss='mse')

# %%
# Print initial weights
weights = model.layers[0].get_weights()
w_init = weights[0][0][0]
b_init = weights[1][0]
print('Linear regression model is initialized with weights w: %.2f, b: %.2f' % (w_init, b_init))
# Out:
# Linear regression model is initialized with weights w: 0.03, b: 0.00

# %%
# Train
model.fit(trX, trY, nb_epoch=83, validation_split=0.2, batch_size=10, verbose=1)
# Out:
# Train on 80 samples, validate on 21 samples
# Epoch 1/10
# 80/80 [==============================] - 0s - loss: 0.1230 - val_loss: 0.1961
# Epoch 2/10
# 80/80 [==============================] - 0s - loss: 0.1229 - val_loss: 0.1923
# Epoch 3/10
# 80/80 [==============================] - 0s - loss: 0.1227 - val_loss: 0.1883
# Epoch 4/10
# 80/80 [==============================] - 0s - loss: 0.1221 - val_loss: 0.1845
# Epoch 5/10
# 80/80 [==============================] - 0s - loss: 0.1219 - val_loss: 0.1811
# Epoch 6/10
# 80/80 [==============================] - 0s - loss: 0.1218 - val_loss: 0.1774
# Epoch 7/10
# 80/80 [==============================] - 0s - loss: 0.1214 - val_loss: 0.1740
# Epoch 8/10
# 80/80 [==============================] - 0s - loss: 0.1212 - val_loss: 0.1708
# Epoch 9/10
# 80/80 [==============================] - 0s - loss: 0.1213 - val_loss: 0.1675
# Epoch 10/10
# 80/80 [==============================] - 0s - loss: 0.1209 - val_loss: 0.1646

# %%
# Print trained weights
weights = model.layers[0].get_weights()
w = weights[0][0][0]
b = weights[1][0]
print('Linear regression model is trained with weights w: %.2f, b: %.2f' % (w, b))
# Out:
# Linear regression model is trained with weights w: 1.72, b: -0.07

# %%
plt.plot(trX, trY, label='data')
plt.plot(trX, w_init*trX + b_init, label='init')
plt.plot(trX, w*trX + b, label='fit')
plt.legend()
plt.show()
