# %% [markdown]
# # State Farm Distracted Driver Detection - implemented from scratch without using VGG16

# %% [markdown]
# ### First get standard boilerplate imports out of the way

# %%
# %matplotlib inline

# %%
from __future__ import division,print_function

import os, json, glob, csv
from time import time
#from glob import glob
import numpy as np
np.set_printoptions(precision=4, linewidth=100)
from matplotlib import pyplot as plt

# %% [markdown]
# ### Define path and batch_size for desired data source

# %%
batch_size = 64

# %%
#path = "data/"
#test_path = "data/test/"

path = "data/sample/"
test_path = "data/sample/test/"

# %%
def get_image_driver_mapping():
    image_driver_mapping = {}
    path = os.path.join('data', 'driver_imgs_list.csv')
    with open(path, 'rb') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',')
        for row in csvreader:
            driver_id = row[0]
            class_id = row[1]
            image_filename = row[2]
            image_driver_mapping[image_filename] = driver_id
            
    return image_driver_mapping

# %%
drivers = get_image_driver_mapping()
drivers
# Out:
# {'img_73362.jpg': 'p064',
#  'img_33297.jpg': 'p049',
#  'img_11836.jpg': 'p066',
#  'img_51329.jpg': 'p061',
#  'img_31913.jpg': 'p014',
#  'img_47981.jpg': 'p035',
#  'img_9480.jpg': 'p050',
#  'img_101593.jpg': 'p014',
#  'img_100057.jpg': 'p002',
#  'img_88441.jpg': 'p050',
#  'img_68136.jpg': 'p050',
#  'img_14949.jpg': 'p002',
#  'img_86167.jpg': 'p012',
#  'img_70959.jpg': 'p022',
#  'img_13308.jpg': 'p045',
#  'img_5503.jpg': 'p014',
#  'img_7514.jpg': 'p021',
#  'img_64065.jpg': 'p024',
#  'img_253.jpg': 'p072',
#  'img_25103.jpg': 'p024',
#  'img_13053.jpg': 'p041',
#  'img_48413.jpg': 'p022',
#  'img_64185.jpg': 'p064',
#  'img_24866.jpg': 'p075',
#  'img_57076.jpg': 'p021',
#  'img_59150.jpg': 'p024',
#  'img_2730.jpg': 'p061',
#  'img_48390.jpg': 'p064',
#  'img_47451.jpg': 'p066',
#  'img_63304.jpg': 'p066',
#  'img_52622.jpg': 'p021',
#  'img_94562.jpg': 'p024',
#  'img_79007.jpg': 'p024',
#  'img_17764.jpg': 'p026',
#  'img_37288.jpg': 'p012',
#  'img_57030.jpg': 'p081',
#  'img_4983.jpg': 'p061',
#  'img_149.jpg': 'p024',
#  'img_52360.jpg': 'p052',
#  'img_51995.jpg': 'p075',
#  'img_59557.jpg': 'p012',
#  'img_50388.jpg': 'p002',
#  'img_72786.jpg': 'p016',
#  'img_94521.jpg': 'p026',
#  'img_12579.jpg': 'p021',
#  'img_44471.jpg': 'p052',
#  'img_35657.jpg': 'p075',
#  'img_83470.jpg': 'p002',
#  'img_87968.jpg': 'p061',
#  'img_36200.jpg': 'p047',
#  'img_97631.jpg': 'p064',
#  'img_66265.jpg': 'p049',
#  'img_29918.jpg': 'p081',
#  'img_100777.jpg': 'p002',
#  'img_40417.jpg': 'p061',
#  'img_31341.jpg': 'p051',
#  'img_87011.jpg': 'p026',
#  'img_47421.jpg': 'p016',
#  'img_37057.jpg': 'p050',
#  'img_57153.jpg': 'p035',
#  'img_47747.jpg': 'p066',
#  'img_85885.jpg': 'p022',
#  'img_2263.jpg': 'p024',
#  'img_63641.jpg': 'p024',
#  'img_34526.jpg': 'p024',
#  'img_39553.jpg': 'p024',
#  'img_60764.jpg': 'p016',
#  'img_28902.jpg': 'p012',
#  'img_23827.jpg': 'p021',
#  'img_28715.jpg': 'p051',
#  'img_216.jpg': 'p014',
#  'img_92450.jpg': 'p016',
#  'img_30341.jpg': 'p022',
#  'img_93352.jpg': 'p066',
#  'img_38398.jpg': 'p024',
#  'img_90774.jpg': 'p026',
#  'img_58117.jpg': 'p042',
#  'img_62305.jpg': 'p052',
#  'img_60408.jpg': 'p014',
#  'img_97738.jpg': 'p041',
#  'img_80085.jpg': 'p081',
#  'img_48714.jpg': 'p015',
#  'img_18208.jpg': 'p041',
#  'img_44796.jpg': 'p024',
#  'img_67811.jpg': 'p022',
#  'img_61610.jpg': 'p041',
#  'img_20643.jpg': 'p047',
#  'img_38469.jpg': 'p026',
#  'img_5749.jpg': 'p081',
#  'img_32031.jpg': 'p026',
#  'img_1723.jpg': 'p024',
#  'img_66323.jpg': 'p021',
#  'img_89037.jpg': 'p041',
#  'img_61038.jpg': 'p041',
#  'img_66761.jpg': 'p035',
#  'img_36460.jpg': 'p024',
#  'img_76466.jpg': 'p022',
#  'img_44615.jpg': 'p045',
#  'img_84060.jpg': 'p016',
#  'img_77878.jpg': 'p047',
#  'img_52293.jpg': 'p015',
#  'img_69185.jpg': 'p021',
#  'img_97880.jpg': 'p075',
#  'img_64535.jpg': 'p061',
#  'img_17741.jpg': 'p016',
#  'img_10034.jpg': 'p002',
#  'img_50246.jpg': 'p012',
#  'img_94608.jpg': 'p002',
#  'img_70605.jpg': 'p041',
#  'img_81562.jpg': 'p052',
#  'img_78961.jpg': 'p035',
#  'img_14430.jpg': 'p056',
#  'img_36888.jpg': 'p024',
#  'img_26706.jpg': 'p051',
#  'img_16810.jpg': 'p026',
#  'img_48583.jpg': 'p015',
#  'img_30473.jpg': 'p064',
#  'img_52830.jpg': 'p051',
#  'img_25076.jpg': 'p051',
#  'img_93354.jpg': 'p012',
#  'img_73127.jpg': 'p026',
#  'img_100116.jpg': 'p002',
#  'img_74512.jpg': 'p049',
#  'img_57604.jpg': 'p045',
#  'img_13365.jpg': 'p042',
#  'img_100429.jpg': 'p041',
#  'img_91800.jpg': 'p075',
#  'img_35005.jpg': 'p022',
#  'img_8065.jpg': 'p024',
#  'img_70712.jpg': 'p016',
#  'img_61131.jpg': 'p049',
#  'img_28714.jpg': 'p021',
#  'img_17592.jpg': 'p066',
#  'img_74078.jpg': 'p061',
#  'img_24927.jpg': 'p039',
#  'img_88290.jpg': 'p049',
#  'img_48176.jpg': 'p024',
#  'img_803.jpg': 'p002',
#  'img_26695.jpg': 'p066',
#  'img_79542.jpg': 'p047',
#  'img_73146.jpg': 'p012',
#  'img_23007.jpg': 'p052',
#  'img_13859.jpg': 'p052',
#  'img_34290.jpg': 'p049',
#  'img_74372.jpg': 'p049',
#  'img_95155.jpg': 'p052',
#  'img_75233.jpg': 'p056',
#  'img_73908.jpg': 'p049',
#  'img_101850.jpg': 'p026',
#  'img_33484.jpg': 'p049',
#  'img_61176.jpg': 'p049',
#  'img_25255.jpg': 'p014',
#  'img_46359.jpg': 'p056',
#  'img_84279.jpg': 'p056',
#  'img_44341.jpg': 'p075',
#  'img_79025.jpg': 'p052',
#  'img_70374.jpg': 'p075',
#  'img_772.jpg': 'p066',
#  'img_51478.jpg': 'p015',
#  'img_32439.jpg': 'p014',
#  'img_91804.jpg': 'p039',
#  'img_56396.jpg': 'p014',
#  'img_7374.jpg': 'p026',
#  'img_8191.jpg': 'p002',
#  'img_24145.jpg': 'p015',
#  'img_33479.jpg': 'p015',
#  'img_1530.jpg': 'p052',
#  'img_54294.jpg': 'p064',
#  'img_23736.jpg': 'p022',
#  'img_18053.jpg': 'p022',
#  'img_83377.jpg': 'p021',
#  'img_88381.jpg': 'p015',
#  'img_101437.jpg': 'p045',
#  'img_86795.jpg': 'p022',
#  'img_68514.jpg': 'p024',
#  'img_33353.jpg': 'p047',
#  'img_38727.jpg': 'p041',
#  'img_8764.jpg': 'p061',
#  'img_30445.jpg': 'p039',
#  'img_80112.jpg': 'p047',
#  'img_17174.jpg': 'p061',
#  'img_31461.jpg': 'p021',
#  'img_61353.jpg': 'p056',
#  'img_16550.jpg': 'p002',
#  'img_84706.jpg': 'p051',
#  'img_23108.jpg': 'p061',
#  'img_41863.jpg': 'p050',
#  'img_44101.jpg': 'p075',
#  'img_43219.jpg': 'p047',
#  'img_76564.jpg': 'p026',
#  'img_87971.jpg': 'p061',
#  'img_80566.jpg': 'p014',
#  'img_82190.jpg': 'p024',
#  'img_57458.jpg': 'p061',
#  'img_77854.jpg': 'p064',
#  'img_18656.jpg': 'p049',
#  'img_9596.jpg': 'p015',
#  'img_30638.jpg': 'p035',
#  'img_68068.jpg': 'p049',
#  'img_29323.jpg': 'p035',
#  'img_8081.jpg': 'p016',
#  'img_59342.jpg': 'p056',
#  'img_75902.jpg': 'p012',
#  'img_77456.jpg': 'p064',
#  'img_16988.jpg': 'p022',
#  'img_68054.jpg': 'p075',
#  'img_11324.jpg': 'p012',
#  'img_71532.jpg': 'p026',
#  'img_79307.jpg': 'p016',
#  'img_72027.jpg': 'p026',
#  'img_13935.jpg': 'p042',
#  'img_20265.jpg': 'p026',
#  'img_17854.jpg': 'p016',
#  'img_31692.jpg': 'p016',
#  'img_54829.jpg': 'p081',
#  'img_16816.jpg': 'p052',
#  'img_83528.jpg': 'p022',
#  'img_23269.jpg': 'p016',
#  'img_54091.jpg': 'p056',
#  'img_79944.jpg': 'p012',
#  'img_29065.jpg': 'p052',
#  'img_5248.jpg': 'p014',
#  'img_7659.jpg': 'p064',
#  'img_90851.jpg': 'p042',
#  'img_68941.jpg': 'p051',
#  'img_4363.jpg': 'p066',
#  'img_26231.jpg': 'p039',
#  'img_32438.jpg': 'p015',
#  'img_10247.jpg': 'p015',
#  'img_1198.jpg': 'p064',
#  'img_51189.jpg': 'p002',
#  'img_67675.jpg': 'p051',
#  'img_71003.jpg': 'p021',
#  'img_74024.jpg': 'p050',
#  'img_67542.jpg': 'p042',
#  'img_44909.jpg': 'p075',
#  'img_39554.jpg': 'p026',
#  'img_22180.jpg': 'p075',
#  'img_5401.jpg': 'p050',
#  'img_23655.jpg': 'p039',
#  'img_56466.jpg': 'p026',
#  'img_88291.jpg': 'p075',
#  'img_86771.jpg': 'p056',
#  'img_54004.jpg': 'p014',
#  'img_57804.jpg': 'p051',
#  'img_82290.jpg': 'p066',
#  'img_84716.jpg': 'p015',
#  'img_52457.jpg': 'p035',
#  'img_50384.jpg': 'p042',
#  'img_88739.jpg': 'p041',
#  'img_55449.jpg': 'p052',
#  'img_53159.jpg': 'p045',
#  'img_81903.jpg': 'p041',
#  'img_56602.jpg': 'p081',
#  'img_40093.jpg': 'p002',
#  'img_23460.jpg': 'p056',
#  'img_59456.jpg': 'p052',
#  'img_37912.jpg': 'p016',
#  'img_69621.jpg': 'p026',
#  'img_77127.jpg': 'p081',
#  'img_94750.jpg': 'p047',
#  'img_55344.jpg': 'p049',
#  'img_2434.jpg': 'p026',
#  'img_42751.jpg': 'p024',
#  'img_80853.jpg': 'p015',
#  'img_76921.jpg': 'p051',
#  'img_42257.jpg': 'p064',
#  'img_21749.jpg': 'p049',
#  'img_66565.jpg': 'p047',
#  'img_8763.jpg': 'p015',
#  'img_31588.jpg': 'p075',
#  'img_49212.jpg': 'p049',
#  'img_42475.jpg': 'p049',
#  'img_41187.jpg': 'p002',
#  'img_94852.jpg': 'p049',
#  'img_35088.jpg': 'p051',
#  'img_80561.jpg': 'p024',
#  'img_40258.jpg': 'p014',
#  'img_38563.jpg': 'p075',
#  'img_97518.jpg': 'p064',
#  'img_47075.jpg': 'p064',
#  'img_48752.jpg': 'p026',
#  'img_83672.jpg': 'p026',
#  'img_4409.jpg': 'p047',
#  'img_60925.jpg': 'p026',
#  'img_46827.jpg': 'p045',
#  'img_84694.jpg': 'p064',
#  'img_66822.jpg': 'p064',
#  'img_296.jpg': 'p024',
#  'img_50789.jpg': 'p075',
#  'img_64810.jpg': 'p051',
#  'img_60192.jpg': 'p024',
#  'img_54686.jpg': 'p049',
#  'img_68722.jpg': 'p024',
#  'img_64755.jpg': 'p049',
#  'img_47798.jpg': 'p026',
#  'img_95463.jpg': 'p024',
#  'img_28169.jpg': 'p016',
#  'img_25156.jpg': 'p052',
#  'img_48499.jpg': 'p056',
#  'img_86427.jpg': 'p015',
#  'img_73160.jpg': 'p014',
#  'img_50806.jpg': 'p039',
#  'img_25763.jpg': 'p075',
#  'img_84030.jpg': 'p052',
#  'img_36911.jpg': 'p052',
#  'img_4518.jpg': 'p021',
#  'img_5175.jpg': 'p056',
#  'img_41400.jpg': 'p064',
#  'img_11003.jpg': 'p061',
#  'img_94410.jpg': 'p052',
#  'img_93998.jpg': 'p024',
#  'img_17897.jpg': 'p066',
#  'img_10425.jpg': 'p056',
#  'img_1190.jpg': 'p066',
#  'img_72440.jpg': 'p024',
#  'img_12963.jpg': 'p050',
#  'img_24630.jpg': 'p015',
#  'img_29829.jpg': 'p061',
#  'img_2514.jpg': 'p047',
#  'img_49686.jpg': 'p016',
#  'img_56305.jpg': 'p066',
#  'img_64982.jpg': 'p045',
#  'img_65842.jpg': 'p072',
#  'img_87297.jpg': 'p051',
#  'img_68901.jpg': 'p035',
#  'img_23919.jpg': 'p026',
#  'img_55578.jpg': 'p081',
#  'img_65742.jpg': 'p049',
#  'img_97660.jpg': 'p022',
#  'img_75207.jpg': 'p026',
#  'img_94559.jpg': 'p024',
#  'img_32949.jpg': 'p047',
#  'img_1053.jpg': 'p072',
#  'img_83726.jpg': 'p026',
#  'img_101544.jpg': 'p026',
#  'img_45692.jpg': 'p064',
#  'img_37663.jpg': 'p021',
#  'img_84352.jpg': 'p050',
#  'img_101944.jpg': 'p050',
#  'img_86725.jpg': 'p014',
#  'img_26875.jpg': 'p015',
#  'img_53158.jpg': 'p014',
#  'img_23156.jpg': 'p012',
#  'img_40535.jpg': 'p024',
#  'img_61253.jpg': 'p081',
#  'img_13090.jpg': 'p045',
#  'img_5646.jpg': 'p052',
#  'img_92413.jpg': 'p026',
#  'img_472.jpg': 'p015',
#  'img_95619.jpg': 'p022',
#  'img_61942.jpg': 'p002',
#  'img_83257.jpg': 'p016',
#  'img_83884.jpg': 'p016',
#  'img_89571.jpg': 'p075',
#  'img_45608.jpg': 'p066',
#  'img_63769.jpg': 'p021',
#  'img_30524.jpg': 'p056',
#  'img_37508.jpg': 'p041',
#  'img_29726.jpg': 'p015',
#  'img_19266.jpg': 'p022',
#  'img_99262.jpg': 'p026',
#  'img_30013.jpg': 'p024',
#  'img_32382.jpg': 'p021',
#  'img_45396.jpg': 'p047',
#  'img_54300.jpg': 'p035',
#  'img_9346.jpg': 'p026',
#  'img_40658.jpg': 'p024',
#  'img_4353.jpg': 'p041',
#  'img_91797.jpg': 'p024',
#  'img_9252.jpg': 'p052',
#  'img_19580.jpg': 'p064',
#  'img_65566.jpg': 'p002',
#  'img_45932.jpg': 'p064',
#  'img_26239.jpg': 'p012',
#  'img_90820.jpg': 'p021',
#  'img_64455.jpg': 'p066',
#  'img_59701.jpg': 'p015',
#  'img_11067.jpg': 'p035',
#  'img_5474.jpg': 'p064',
#  'img_7414.jpg': 'p064',
#  'img_24808.jpg': 'p049',
#  'img_59560.jpg': 'p066',
#  'img_58979.jpg': 'p061',
#  'img_8300.jpg': 'p075',
#  'img_13902.jpg': 'p042',
#  'img_72487.jpg': 'p045',
#  'img_17591.jpg': 'p056',
#  'img_86528.jpg': 'p012',
#  'img_95555.jpg': 'p064',
#  'img_22983.jpg': 'p075',
#  'img_40578.jpg': 'p026',
#  'img_28141.jpg': 'p066',
#  'img_84935.jpg': 'p016',
#  'img_29909.jpg': 'p021',
#  'img_68377.jpg': 'p014',
#  'img_48528.jpg': 'p035',
#  'img_98882.jpg': 'p047',
#  'img_91785.jpg': 'p021',
#  'img_21469.jpg': 'p035',
#  'img_62784.jpg': 'p026',
#  'img_4927.jpg': 'p022',
#  'img_17673.jpg': 'p041',
#  'img_48340.jpg': 'p035',
#  'img_54984.jpg': 'p066',
#  'img_27870.jpg': 'p061',
#  'img_83885.jpg': 'p024',
#  'img_95140.jpg': 'p045',
#  'img_33094.jpg': 'p024',
#  'img_14736.jpg': 'p024',
#  'img_46053.jpg': 'p026',
#  'img_63031.jpg': 'p042',
#  'img_71230.jpg': 'p021',
#  'img_87988.jpg': 'p052',
#  'img_96616.jpg': 'p049',
#  'img_4663.jpg': 'p022',
#  'img_79556.jpg': 'p075',
#  'img_89631.jpg': 'p012',
#  'img_85104.jpg': 'p026',
#  'img_34295.jpg': 'p002',
#  'img_95106.jpg': 'p052',
#  'img_40474.jpg': 'p052',
#  'img_50198.jpg': 'p081',
#  'img_40245.jpg': 'p022',
#  'img_41723.jpg': 'p022',
#  'img_1640.jpg': 'p021',
#  'img_49662.jpg': 'p041',
#  'img_30740.jpg': 'p051',
#  'img_18694.jpg': 'p041',
#  'img_97165.jpg': 'p045',
#  'img_66432.jpg': 'p056',
#  'img_97152.jpg': 'p047',
#  'img_84689.jpg': 'p021',
#  'img_45933.jpg': 'p015',
#  'img_89355.jpg': 'p066',
#  'img_67495.jpg': 'p047',
#  'img_14485.jpg': 'p075',
#  'img_79445.jpg': 'p022',
#  'img_29633.jpg': 'p002',
#  'img_86776.jpg': 'p024',
#  'img_90765.jpg': 'p035',
#  'img_31684.jpg': 'p015',
#  'img_53925.jpg': 'p021',
#  'img_43519.jpg': 'p061',
#  'img_97525.jpg': 'p041',
#  'img_85222.jpg': 'p041',
#  'img_64817.jpg': 'p064',
#  'img_2631.jpg': 'p035',
#  'img_67859.jpg': 'p026',
#  'img_29908.jpg': 'p049',
#  'img_12544.jpg': 'p050',
#  'img_31871.jpg': 'p042',
#  'img_78611.jpg': 'p015',
#  'img_15379.jpg': 'p050',
#  'img_88957.jpg': 'p066',
#  'img_88676.jpg': 'p075',
#  'img_12248.jpg': 'p021',
#  'img_68376.jpg': 'p072',
#  'img_51338.jpg': 'p014',
#  'img_96912.jpg': 'p024',
#  'img_46464.jpg': 'p002',
#  'img_28366.jpg': 'p015',
#  'img_80267.jpg': 'p024',
#  'img_12736.jpg': 'p035',
#  'img_32025.jpg': 'p061',
#  'img_76561.jpg': 'p026',
#  'img_1197.jpg': 'p035',
#  'img_58376.jpg': 'p050',
#  'img_76395.jpg': 'p016',
#  'img_58206.jpg': 'p021',
#  'img_16693.jpg': 'p026',
#  'img_78515.jpg': 'p042',
#  'img_1069.jpg': 'p021',
#  'img_71925.jpg': 'p026',
#  'img_75671.jpg': 'p026',
#  'img_96584.jpg': 'p056',
#  'img_11416.jpg': 'p039',
#  'img_18356.jpg': 'p051',
#  'img_11920.jpg': 'p012',
#  'img_21880.jpg': 'p024',
#  'img_31795.jpg': 'p051',
#  'img_52125.jpg': 'p022',
#  'img_67167.jpg': 'p024',
#  'img_81693.jpg': 'p056',
#  'img_23350.jpg': 'p024',
#  'img_30431.jpg': 'p056',
#  'img_71755.jpg': 'p050',
#  'img_82320.jpg': 'p016',
#  'img_63248.jpg': 'p035',
#  'img_32870.jpg': 'p052',
#  'img_43370.jpg': 'p002',
#  'img_82902.jpg': 'p051',
#  'img_21452.jpg': 'p039',
#  'img_75489.jpg': 'p026',
#  'img_42021.jpg': 'p075',
#  'img_26907.jpg': 'p012',
#  'img_23948.jpg': 'p041',
#  'img_94140.jpg': 'p002',
#  'img_85059.jpg': 'p045',
#  'img_83371.jpg': 'p051',
#  'img_26202.jpg': 'p045',
#  'img_4483.jpg': 'p014',
#  'img_77083.jpg': 'p049',
#  'img_61909.jpg': 'p049',
#  'img_43441.jpg': 'p072',
#  'img_2925.jpg': 'p051',
#  'img_10357.jpg': 'p051',
#  'img_56440.jpg': 'p016',
#  'img_66860.jpg': 'p024',
#  'img_36900.jpg': 'p051',
#  'img_94398.jpg': 'p024',
#  'img_31659.jpg': 'p064',
#  'img_36333.jpg': 'p024',
#  'img_88956.jpg': 'p081',
#  'img_24252.jpg': 'p066',
#  'img_48076.jpg': 'p042',
#  'img_80253.jpg': 'p015',
#  'img_14966.jpg': 'p021',
#  'img_56616.jpg': 'p012',
#  'img_34080.jpg': 'p035',
#  'img_55360.jpg': 'p066',
#  'img_35349.jpg': 'p052',
#  'img_25980.jpg': 'p016',
#  'img_87160.jpg': 'p049',
#  'img_64769.jpg': 'p012',
#  'img_76339.jpg': 'p052',
#  'img_8457.jpg': 'p050',
#  'img_77122.jpg': 'p021',
#  'img_9275.jpg': 'p015',
#  'img_13970.jpg': 'p052',
#  'img_54145.jpg': 'p075',
#  'img_91307.jpg': 'p026',
#  'img_77334.jpg': 'p022',
#  'img_4853.jpg': 'p021',
#  'img_10198.jpg': 'p049',
#  'img_43195.jpg': 'p045',
#  'img_63344.jpg': 'p075',
#  'img_47383.jpg': 'p052',
#  'img_20474.jpg': 'p052',
#  'img_46141.jpg': 'p014',
#  'img_99785.jpg': 'p064',
#  'img_62528.jpg': 'p015',
#  'img_29976.jpg': 'p026',
#  'img_94547.jpg': 'p021',
#  'img_84656.jpg': 'p066',
#  'img_98139.jpg': 'p022',
#  'img_63607.jpg': 'p021',
#  'img_70817.jpg': 'p056',
#  'img_63958.jpg': 'p061',
#  'img_83762.jpg': 'p024',
#  'img_33064.jpg': 'p075',
#  'img_53014.jpg': 'p039',
#  'img_93277.jpg': 'p024',
#  'img_89206.jpg': 'p026',
#  'img_32479.jpg': 'p051',
#  'img_23701.jpg': 'p075',
#  'img_1323.jpg': 'p042',
#  'img_66645.jpg': 'p066',
#  'img_63140.jpg': 'p075',
#  'img_100456.jpg': 'p022',
#  'img_84019.jpg': 'p052',
#  'img_32926.jpg': 'p035',
#  'img_20347.jpg': 'p075',
#  'img_15074.jpg': 'p049',
#  'img_17109.jpg': 'p041',
#  'img_78936.jpg': 'p061',
#  'img_46018.jpg': 'p047',
#  'img_76616.jpg': 'p050',
#  'img_30234.jpg': 'p021',
#  'img_95339.jpg': 'p015',
#  'img_46655.jpg': 'p072',
#  'img_27691.jpg': 'p045',
#  'img_100568.jpg': 'p042',
#  'img_66034.jpg': 'p035',
#  'img_26228.jpg': 'p012',
#  'img_6571.jpg': 'p022',
#  'img_19085.jpg': 'p024',
#  'img_36003.jpg': 'p066',
#  'img_96525.jpg': 'p042',
#  'img_5875.jpg': 'p049',
#  'img_43043.jpg': 'p026',
#  'img_49364.jpg': 'p039',
#  'img_21235.jpg': 'p016',
#  'img_64977.jpg': 'p022',
#  'img_64319.jpg': 'p056',
#  'img_19773.jpg': 'p045',
#  'img_59660.jpg': 'p021',
#  'img_24929.jpg': 'p021',
#  'img_62412.jpg': 'p014',
#  'img_44655.jpg': 'p042',
#  'img_95048.jpg': 'p012',
#  'img_65428.jpg': 'p014',
#  'img_71544.jpg': 'p016',
#  'img_94205.jpg': 'p026',
#  'img_92653.jpg': 'p012',
#  'img_81706.jpg': 'p026',
#  'img_47157.jpg': 'p042',
#  'img_73509.jpg': 'p012',
#  'img_51389.jpg': 'p075',
#  'img_35717.jpg': 'p049',
#  'img_81129.jpg': 'p039',
#  'img_29977.jpg': 'p002',
#  'img_84433.jpg': 'p075',
#  'img_30112.jpg': 'p021',
#  'img_97399.jpg': 'p022',
#  'img_42744.jpg': 'p024',
#  'img_138.jpg': 'p045',
#  'img_40065.jpg': 'p002',
#  'img_39343.jpg': 'p051',
#  'img_37476.jpg': 'p056',
#  'img_22343.jpg': 'p052',
#  'img_92859.jpg': 'p021',
#  'img_78546.jpg': 'p002',
#  'img_15503.jpg': 'p052',
#  'img_45874.jpg': 'p026',
#  'img_6421.jpg': 'p022',
#  'img_67359.jpg': 'p050',
#  'img_27764.jpg': 'p051',
#  'img_15312.jpg': 'p021',
#  'img_21650.jpg': 'p021',
#  'img_84636.jpg': 'p064',
#  'img_64929.jpg': 'p014',
#  'img_85737.jpg': 'p075',
#  'img_21889.jpg': 'p072',
#  'img_23267.jpg': 'p042',
#  'img_89985.jpg': 'p066',
#  'img_86599.jpg': 'p014',
#  'img_63265.jpg': 'p056',
#  'img_39821.jpg': 'p081',
#  'img_85596.jpg': 'p035',
#  'img_56274.jpg': 'p081',
#  'img_6570.jpg': 'p022',
#  'img_68161.jpg': 'p041',
#  'img_28717.jpg': 'p061',
#  'img_47349.jpg': 'p002',
#  'img_59357.jpg': 'p022',
#  'img_61122.jpg': 'p081',
#  'img_22258.jpg': 'p051',
#  'img_92534.jpg': 'p026',
#  'img_96814.jpg': 'p022',
#  'img_64625.jpg': 'p039',
#  'img_69693.jpg': 'p014',
#  'img_52244.jpg': 'p051',
#  'img_19078.jpg': 'p047',
#  'img_33368.jpg': 'p061',
#  'img_51013.jpg': 'p016',
#  'img_24232.jpg': 'p026',
#  'img_16214.jpg': 'p061',
#  'img_37376.jpg': 'p050',
#  'img_87882.jpg': 'p041',
#  'img_52348.jpg': 'p052',
#  'img_52787.jpg': 'p045',
#  'img_38023.jpg': 'p047',
#  'img_98375.jpg': 'p061',
#  'img_78163.jpg': 'p024',
#  'img_28206.jpg': 'p016',
#  'img_57324.jpg': 'p014',
#  'img_49693.jpg': 'p045',
#  'img_28354.jpg': 'p024',
#  'img_42547.jpg': 'p002',
#  'img_98126.jpg': 'p026',
#  'img_44861.jpg': 'p014',
#  'img_47839.jpg': 'p012',
#  'img_43958.jpg': 'p015',
#  'img_32279.jpg': 'p066',
#  'img_66670.jpg': 'p075',
#  'img_35673.jpg': 'p021',
#  'img_6645.jpg': 'p045',
#  'img_17677.jpg': 'p051',
#  'img_12267.jpg': 'p012',
#  'img_82757.jpg': 'p022',
#  'img_85823.jpg': 'p041',
#  'img_73423.jpg': 'p026',
#  'img_96297.jpg': 'p039',
#  'img_4149.jpg': 'p021',
#  'img_42312.jpg': 'p015',
#  'img_99179.jpg': 'p014',
#  'img_93190.jpg': 'p052',
#  'img_15429.jpg': 'p042',
#  'img_65920.jpg': 'p047',
#  'img_86343.jpg': 'p049',
#  'img_20549.jpg': 'p064',
#  'img_69280.jpg': 'p066',
#  'img_69967.jpg': 'p012',
#  'img_9057.jpg': 'p039',
#  'img_39371.jpg': 'p014',
#  'img_57654.jpg': 'p056',
#  'img_52919.jpg': 'p021',
#  'img_16683.jpg': 'p056',
#  'img_37275.jpg': 'p016',
#  'img_33391.jpg': 'p022',
#  'img_40307.jpg': 'p012',
#  'img_23287.jpg': 'p049',
#  'img_31681.jpg': 'p081',
#  'img_11132.jpg': 'p056',
#  'img_53384.jpg': 'p039',
#  'img_6475.jpg': 'p049',
#  'img_53931.jpg': 'p012',
#  'img_42144.jpg': 'p075',
#  'img_57083.jpg': 'p024',
#  'img_26382.jpg': 'p052',
#  'img_77066.jpg': 'p075',
#  'img_50348.jpg': 'p066',
#  'img_32167.jpg': 'p022',
#  'img_30861.jpg': 'p075',
#  'img_76082.jpg': 'p012',
#  'img_63693.jpg': 'p026',
#  'img_36717.jpg': 'p026',
#  'img_16874.jpg': 'p045',
#  'img_157.jpg': 'p066',
#  'img_57931.jpg': 'p072',
#  'img_32444.jpg': 'p021',
#  'img_61077.jpg': 'p061',
#  'img_33888.jpg': 'p081',
#  'img_42533.jpg': 'p024',
#  'img_76979.jpg': 'p015',
#  'img_1790.jpg': 'p002',
#  'img_67707.jpg': 'p075',
#  'img_70150.jpg': 'p002',
#  'img_64762.jpg': 'p061',
#  'img_21812.jpg': 'p061',
#  'img_43280.jpg': 'p064',
#  'img_83623.jpg': 'p014',
#  'img_35280.jpg': 'p022',
#  'img_36645.jpg': 'p052',
#  'img_52243.jpg': 'p050',
#  'img_13623.jpg': 'p015',
#  'img_82756.jpg': 'p039',
#  'img_29378.jpg': 'p049',
#  'img_2388.jpg': 'p061',
#  'img_86888.jpg': 'p016',
#  'img_3961.jpg': 'p021',
#  'img_85173.jpg': 'p081',
#  'img_33788.jpg': 'p024',
#  'img_83921.jpg': 'p066',
#  'img_83071.jpg': 'p052',
#  'img_36943.jpg': 'p042',
#  'img_92826.jpg': 'p061',
#  'img_98577.jpg': 'p026',
#  'img_34130.jpg': 'p042',
#  'img_48278.jpg': 'p015',
#  'img_14483.jpg': 'p022',
#  'img_97825.jpg': 'p014',
#  'img_63976.jpg': 'p081',
#  'img_78034.jpg': 'p039',
#  'img_34609.jpg': 'p012',
#  'img_86483.jpg': 'p064',
#  'img_62670.jpg': 'p024',
#  'img_18819.jpg': 'p035',
#  'img_3442.jpg': 'p026',
#  'img_82937.jpg': 'p064',
#  'img_37693.jpg': 'p052',
#  'img_56031.jpg': 'p002',
#  'img_63381.jpg': 'p021',
#  'img_8807.jpg': 'p035',
#  'img_6972.jpg': 'p015',
#  'img_72999.jpg': 'p002',
#  'img_73233.jpg': 'p045',
#  'img_32714.jpg': 'p081',
#  'img_16858.jpg': 'p026',
#  'img_86359.jpg': 'p042',
#  'img_75992.jpg': 'p026',
#  'img_45657.jpg': 'p066',
#  'img_80864.jpg': 'p039',
#  'img_26581.jpg': 'p035',
#  'img_10361.jpg': 'p075',
#  'img_67186.jpg': 'p075',
#  'img_92464.jpg': 'p014',
#  'img_50905.jpg': 'p026',
#  'img_57259.jpg': 'p047',
#  'img_94745.jpg': 'p064',
#  'img_9564.jpg': 'p012',
#  'img_50852.jpg': 'p016',
#  'img_44114.jpg': 'p002',
#  'img_43091.jpg': 'p035',
#  'img_42024.jpg': 'p081',
#  'img_65622.jpg': 'p061',
#  'img_10481.jpg': 'p026',
#  'img_78372.jpg': 'p035',
#  'img_2810.jpg': 'p016',
#  'img_16473.jpg': 'p015',
#  'img_27012.jpg': 'p022',
#  'img_69842.jpg': 'p049',
#  'img_61415.jpg': 'p015',
#  'img_62587.jpg': 'p024',
#  'img_11171.jpg': 'p021',
#  'img_60990.jpg': 'p066',
#  'img_77458.jpg': 'p066',
#  'img_97229.jpg': 'p022',
#  'img_79395.jpg': 'p024',
#  'img_99822.jpg': 'p012',
#  'img_13447.jpg': 'p022',
#  'img_37525.jpg': 'p039',
#  'img_88359.jpg': 'p039',
#  'img_49785.jpg': 'p002',
#  'img_26519.jpg': 'p081',
#  'img_65941.jpg': 'p061',
#  'img_14778.jpg': 'p064',
#  'img_96522.jpg': 'p012',
#  'img_67110.jpg': 'p024',
#  'img_3214.jpg': 'p041',
#  'img_24623.jpg': 'p066',
#  'img_41704.jpg': 'p039',
#  'img_421.jpg': 'p056',
#  'img_75753.jpg': 'p016',
#  'img_5145.jpg': 'p064',
#  'img_85245.jpg': 'p041',
#  'img_92020.jpg': 'p051',
#  'img_23337.jpg': 'p051',
#  'img_4053.jpg': 'p035',
#  'img_28957.jpg': 'p022',
#  'img_62517.jpg': 'p021',
#  'img_30953.jpg': 'p072',
#  'img_59764.jpg': 'p026',
#  'img_93086.jpg': 'p066',
#  'img_32299.jpg': 'p066',
#  'img_35289.jpg': 'p061',
#  'img_38666.jpg': 'p022',
#  'img_62936.jpg': 'p016',
#  'img_21356.jpg': 'p052',
#  'img_75001.jpg': 'p022',
#  'img_56269.jpg': 'p015',
#  'img_100371.jpg': 'p045',
#  'img_3969.jpg': 'p045',
#  'img_10696.jpg': 'p041',
#  'img_12293.jpg': 'p039',
#  'img_49282.jpg': 'p026',
#  'img_37072.jpg': 'p041',
#  'img_13585.jpg': 'p002',
#  'img_7061.jpg': 'p012',
#  'img_67476.jpg': 'p061',
#  'img_19657.jpg': 'p012',
#  'img_32976.jpg': 'p015',
#  'img_40701.jpg': 'p015',
#  'img_50804.jpg': 'p050',
#  'img_85355.jpg': 'p047',
#  'img_18917.jpg': 'p047',
#  'img_18016.jpg': 'p051',
#  'img_47618.jpg': 'p012',
#  'img_74406.jpg': 'p022',
#  'img_7847.jpg': 'p066',
#  'img_12773.jpg': 'p049',
#  'img_63977.jpg': 'p049',
#  'img_25844.jpg': 'p026',
#  'img_35316.jpg': 'p024',
#  'img_46161.jpg': 'p022',
#  'img_22905.jpg': 'p041',
#  'img_16823.jpg': 'p061',
#  'img_27415.jpg': 'p012',
#  'img_75107.jpg': 'p021',
#  'img_70089.jpg': 'p049',
#  'img_65196.jpg': 'p051',
#  'img_13108.jpg': 'p056',
#  'img_49562.jpg': 'p049',
#  'img_92021.jpg': 'p022',
#  'img_35004.jpg': 'p026',
#  'img_44004.jpg': 'p014',
#  'img_49688.jpg': 'p066',
#  'img_45571.jpg': 'p081',
#  'img_98163.jpg': 'p016',
#  'img_44748.jpg': 'p026',
#  'img_41810.jpg': 'p002',
#  'img_69408.jpg': 'p016',
#  'img_78038.jpg': 'p050',
#  'img_21502.jpg': 'p021',
#  'img_9763.jpg': 'p015',
#  'img_34370.jpg': 'p016',
#  'img_629.jpg': 'p014',
#  'img_85756.jpg': 'p050',
#  'img_63759.jpg': 'p035',
#  'img_91896.jpg': 'p042',
#  'img_38740.jpg': 'p066',
#  'img_91561.jpg': 'p022',
#  'img_79521.jpg': 'p050',
#  'img_32297.jpg': 'p075',
#  'img_22980.jpg': 'p022',
#  'img_72603.jpg': 'p047',
#  'img_17696.jpg': 'p061',
#  'img_85353.jpg': 'p045',
#  'img_35288.jpg': 'p041',
#  'img_28862.jpg': 'p047',
#  'img_22541.jpg': 'p026',
#  'img_62824.jpg': 'p015',
#  'img_64841.jpg': 'p045',
#  'img_70029.jpg': 'p047',
#  'img_9699.jpg': 'p021',
#  'img_28551.jpg': 'p064',
#  'img_89213.jpg': 'p081',
#  'img_61587.jpg': 'p012',
#  'img_40429.jpg': 'p026',
#  'img_32554.jpg': 'p061',
#  'img_49010.jpg': 'p052',
#  'img_100529.jpg': 'p026',
#  'img_36733.jpg': 'p047',
#  'img_55309.jpg': 'p021',
#  'img_18380.jpg': 'p061',
#  'img_78318.jpg': 'p035',
#  'img_30042.jpg': 'p016',
#  'img_80712.jpg': 'p064',
#  'img_54235.jpg': 'p014',
#  'img_70417.jpg': 'p026',
#  'img_80006.jpg': 'p081',
#  'img_55685.jpg': 'p049',
#  'img_99478.jpg': 'p024',
#  'img_67941.jpg': 'p056',
#  'img_88178.jpg': 'p021',
#  'img_34214.jpg': 'p016',
#  'img_23017.jpg': 'p026',
#  'img_87932.jpg': 'p056',
#  'img_62066.jpg': 'p012',
#  'img_33633.jpg': 'p012',
#  'img_50573.jpg': 'p026',
#  'img_57246.jpg': 'p021',
#  'img_84664.jpg': 'p016',
#  'img_65472.jpg': 'p016',
#  'img_14089.jpg': 'p026',
#  'img_17332.jpg': 'p066',
#  'img_49107.jpg': 'p050',
#  'img_89937.jpg': 'p026',
#  'img_20708.jpg': 'p015',
#  'img_15864.jpg': 'p035',
#  'img_67671.jpg': 'p016',
#  'img_33156.jpg': 'p056',
#  'img_34712.jpg': 'p016',
#  'img_73145.jpg': 'p024',
#  'img_86096.jpg': 'p026',
#  'img_26807.jpg': 'p061',
#  'img_37335.jpg': 'p039',
#  'img_71648.jpg': 'p049',
#  'img_14057.jpg': 'p056',
#  'img_49612.jpg': 'p061',
#  'img_87031.jpg': 'p012',
#  'img_92030.jpg': 'p026',
#  'img_70363.jpg': 'p002',
#  'img_32983.jpg': 'p039',
#  'img_79075.jpg': 'p024',
#  'img_32131.jpg': 'p014',
#  'img_95469.jpg': 'p035',
#  'img_85758.jpg': 'p041',
#  'img_17633.jpg': 'p012',
#  'img_91351.jpg': 'p015',
#  'img_16717.jpg': 'p050',
#  'img_74840.jpg': 'p015',
#  'img_12538.jpg': 'p014',
#  'img_11545.jpg': 'p016',
#  'img_91645.jpg': 'p064',
#  'img_48454.jpg': 'p012',
#  'img_5893.jpg': 'p021',
#  'img_74351.jpg': 'p022',
#  'img_63245.jpg': 'p026',
#  'img_62724.jpg': 'p024',
#  'img_82560.jpg': 'p022',
#  'img_85780.jpg': 'p056',
#  'img_55675.jpg': 'p014',
#  'img_36457.jpg': 'p016',
#  'img_42351.jpg': 'p049',
#  'img_91925.jpg': 'p041',
#  'img_93992.jpg': 'p024',
#  'img_89464.jpg': 'p016',
#  'img_18801.jpg': 'p051',
#  'img_28818.jpg': 'p047',
#  'img_47604.jpg': 'p002',
#  'img_15989.jpg': 'p026',
#  'img_92611.jpg': 'p024',
#  'img_20055.jpg': 'p015',
#  'img_55398.jpg': 'p014',
#  'img_23631.jpg': 'p021',
#  'img_20430.jpg': 'p026',
#  'img_89034.jpg': 'p012',
#  'img_22347.jpg': 'p075',
#  'img_68842.jpg': 'p081',
#  'img_20624.jpg': 'p016',
#  'img_89800.jpg': 'p015',
#  'img_2653.jpg': 'p050',
#  'img_66888.jpg': 'p075',
#  'img_76406.jpg': 'p056',
#  'img_22684.jpg': 'p035',
#  'img_77988.jpg': 'p075',
#  'img_57881.jpg': 'p014',
#  'img_28449.jpg': 'p021',
#  'img_20268.jpg': 'p042',
#  'img_39069.jpg': 'p024',
#  'img_94500.jpg': 'p061',
#  'img_10431.jpg': 'p022',
#  'img_50226.jpg': 'p050',
#  'img_29307.jpg': 'p021',
#  'img_3182.jpg': 'p061',
#  'img_76039.jpg': 'p052',
#  'img_15486.jpg': 'p021',
#  'img_23297.jpg': 'p016',
#  'img_68885.jpg': 'p002',
#  'img_71915.jpg': 'p035',
#  'img_69540.jpg': 'p016',
#  'img_89186.jpg': 'p002',
#  'img_87171.jpg': 'p045',
#  'img_36088.jpg': 'p081',
#  'img_101456.jpg': 'p061',
#  'img_23850.jpg': 'p026',
#  'img_29442.jpg': 'p015',
#  'img_60856.jpg': 'p015',
#  ...}

# %%
    

def load_training_data(img_rows, img_cols, color_type=1):
    train_imgs = []
    train_classes = []
    driver_ids = []
    
    
    
    
    
path = os.path.join('data', 'train', 'c0', '*.jpg')
files = glob.glob(path)

# %%
from PIL import Image
img = Image.open(files[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F0E1664E250>

# %% [markdown]
# ## Create simple Convolution model

# %%
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout, Lambda
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.utils.data_utils import get_file
from keras.preprocessing import image
from keras.optimizers import SGD, RMSprop, Adam
# Out:
# Using Theano backend.

# %%
model = Sequential()

# %% [markdown]
# ### Add Input Layer for images with dimension 244 x 244

# %%
model.add(Lambda(vgg_preprocess, input_shape=(3,224,224)))

# %% [markdown]
# ### Add Convolutional Layers

# %%
def ConvBlock(mymodel, layers, filters):
    for i in range(layers):
        mymodel.add(ZeroPadding2D((1,1)))
        mymodel.add(Convolution2D(filters, 3, 3, activation='relu'))
    mymodel.add(MaxPooling2D((2,2), strides=(2,2)))

# %%
ConvBlock(model, 2, 64)
ConvBlock(model, 2, 128)
ConvBlock(model, 3, 256)
ConvBlock(model, 3, 512)
ConvBlock(model, 3, 512)

# %% [markdown]
# ### Add Fully Connected Layers

# %%
def FCBlock(mymodel):
    mymodel.add(Dense(4096, activation='relu'))
    mymodel.add(Dropout(0.5))

# %%
model.add(Flatten())
FCBlock(model)
FCBlock(model)

# %% [markdown]
# ### Add final output Dense Layer

# %%
model.add(Dense(1000, activation='softmax'))

# %% [markdown]
# ### Download and load pre-trained model weights from Imagenet

# %%
fname = 'vgg16.h5'
baseurl = 'http://www.platform.ai/models/'
local_weights = get_file(fname, baseurl+fname, cache_subdir='models')

# %%
model.load_weights(local_weights)

# %% [markdown]
# ## Finetune VGG16 by replacing last layer with a Dense layer

# %%
model.pop()

# %% [markdown]
# Make all remaining layers read-only, since we want to leverage all the pre-trained weights

# %%
for layer in model.layers: layer.trainable=False

# %% [markdown]
# Get batch of data for training and validation

# %%
def get_batches(path, gen=image.ImageDataGenerator(), shuffle=True, batch_size=8, class_mode='categorical'):
    return gen.flow_from_directory(path, target_size=(224,224), class_mode=class_mode, shuffle=shuffle, batch_size=batch_size)

# %%
train_batches = get_batches(path+'train', batch_size=batch_size)
valid_batches = get_batches(path+'valid', batch_size=batch_size)
# Out:
# Found 495 images belonging to 10 classes.
# Found 120 images belonging to 10 classes.

# %% [markdown]
# ### Now add new Dense layer with number of classes we are training with, and compile.

# %%
model.add(Dense(train_batches.nb_class, activation='softmax'))

# %%
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Now fit the model with training and validation batches

# %%
model.fit_generator(train_batches, 
                    samples_per_epoch=train_batches.nb_sample,
                    nb_epoch=2,
                    validation_data=valid_batches,
                    nb_val_samples=valid_batches.nb_sample
                   )
# Out:
# Epoch 1/1
# 495/495 [==============================] - 238s - loss: 6.5452 - acc: 0.2485 - val_loss: 5.6193 - val_acc: 0.2500

# %%
model.optimizer.lr=0.0001
model.fit_generator(train_batches, 
                    samples_per_epoch=train_batches.nb_sample,
                    nb_epoch=4,
                    validation_data=valid_batches,
                    nb_val_samples=valid_batches.nb_sample
                   )
# Out:
# Epoch 1/4
# 495/495 [==============================] - 238s - loss: 5.0569 - acc: 0.3657 - val_loss: 5.4888 - val_acc: 0.1917
# Epoch 2/4
# 495/495 [==============================] - 236s - loss: 4.4836 - acc: 0.4242 - val_loss: 6.6150 - val_acc: 0.3083
# Epoch 3/4
# 495/495 [==============================] - 236s - loss: 4.4030 - acc: 0.4687 - val_loss: 5.4573 - val_acc: 0.2583
# Epoch 4/4
# 495/495 [==============================] - 236s - loss: 4.4733 - acc: 0.4909 - val_loss: 5.0034 - val_acc: 0.3583

# %%
# model.save_weights('models/small_sample.h5')

# %% [markdown]
# ### Generate test predictions

# %%
test_batches = get_batches(test_path, shuffle=False, batch_size=2*batch_size, class_mode=None)
# Out:
# Found 100 images belonging to 1 classes.

# %%
test_predictions = model.predict_generator(test_batches, test_batches.nb_sample)

# %% [markdown]
# ### Generate Kaggle submission file

# %% [markdown]
# So to play it safe, we use a sneaky trick to round down our edge predictions.
# Swap all ones with .95 and all zeros with .05

# %%
test_predictions = test_predictions.clip(min=0.05, max=0.95)

# %% [markdown]
# Prepare filenames by stripping path

# %%
test_filenames = [filename[filename.find('/')+1:] for filename in test_batches.filenames]

# %% [markdown]
# Prepare the submission data matrix the dumb way...

# %%
subm1 = np.zeros(test_batches.nb_sample, dtype=[('filename', 'S128'), ('c0', float), ('c1', float), ('c2', float), ('c3', float), ('c4', float), ('c5', float), ('c6', float), ('c7', float), ('c8', float), ('c9', float)])

subm1['filename'] = test_filenames

subm1['c0'] = test_predictions[:,0]
subm1['c1'] = test_predictions[:,1]
subm1['c2'] = test_predictions[:,2]
subm1['c3'] = test_predictions[:,3]
subm1['c4'] = test_predictions[:,4]
subm1['c5'] = test_predictions[:,5]
subm1['c6'] = test_predictions[:,6]
subm1['c7'] = test_predictions[:,7]
subm1['c8'] = test_predictions[:,8]
subm1['c9'] = test_predictions[:,9]

# %% [markdown]
# Write Kaggle submission file

# %%
submission_file_name = 'submission_' + str(int(time())) + '.csv'
np.savetxt(submission_file_name, subm1, fmt='%s,%.5f,%.5f,%.5f,%.5f,%.5f,%.5f,%.5f,%.5f,%.5f,%.5f', header='img,c0,c1,c2,c3,c4,c5,c6,c7,c8,c9', comments='')

# %% [markdown]
# ### Visualize the prediction by plotting a few

# %% [markdown]
# Define function to convert Category ID encoded via bit vector to Category Description from Kaggle's data description page:
# * c0: safe driving
# * c1: texting - right
# * c2: talking on the phone - right
# * c3: texting - left
# * c4: talking on the phone - left
# * c5: operating the radio
# * c6: drinking
# * c7: reaching behind
# * c8: hair and makeup
# * c9: talking to passenger

# %%
def convertCategetoryIDToTextDescription(category_id):
    return {
        0: 'safe driving',
        1: 'texting - right',
        2: 'talking on the phone - right',
        3: 'texting - left',
        4: 'talking on the phone - left',
        5: 'operating the radio',
        6: 'drinking',
        7: 'reaching behind',
        8: 'hair and makeup',
        9: 'talking to passenger'
    }.get(category_id, 'unknown')

# %% [markdown]
# Use argmax to find index with highest probability.
# Index happens to be same value as State Farm Cateogry Id itself

# %%
test_pred_winning_category_id = test_predictions.argmax(axis=1)
test_pred_winning_categories = [convertCategetoryIDToTextDescription(x) for x in test_pred_winning_category_id]
test_pred_winning_prob = np.choose(test_pred_winning_category_id, test_predictions.transpose())

# %% [markdown]
# Helper function to plot images for chosen indices

# %%
from utils import plots
    
def plots_idx(idx, path, filenames, categories, probabilities):
    my_image_ids = np.array([int(filenames[i][filenames[i].find('_')+1:filenames[i].find('.')]) for i in idx])
    my_categories = [categories[i] for i in idx]
    my_probabilities = [probabilities[i] for i in idx]
    
    # label = <iamge id>=<probability>:<category>
    my_labels = ["{}={:0.2f}:{}".format(i, j, k) for i,j,k in zip(my_image_ids, my_probabilities, my_categories)]
    
    plots([image.load_img(path + filenames[i]) for i in idx], titles=my_labels)

# %%
n_view = 4

idx = np.random.permutation(range(0,test_batches.nb_sample))[:n_view]
plots_idx(idx, test_path, test_batches.filenames, test_pred_winning_categories, test_pred_winning_prob)
